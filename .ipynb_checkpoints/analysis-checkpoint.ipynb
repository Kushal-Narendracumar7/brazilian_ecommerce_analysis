# %%
import pandas as pd 
import seaborn as sns 
import plotly.express as px 
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('datasets/preprocessed_dataset.csv')

# %%
df.head()
# Out:
#                            order_id order_status  \
# 0  e481f51cbdc54678b7cc49136f2d6af7    delivered
# 1  53cdb2fc8bc7dce0b6741e2150273451    delivered
# 2  47770eb9100c2d0c44946d9cf07ec65d    delivered
# 3  949d5b44dbf5de918fe9c16f97b45f8a    delivered
# 4  ad21c59c0840e6cb83a9ceb5573f8159    delivered
#
#                         customer_id                        product_id   price  \
# 0  9ef432eb6251297304e76186b10a928d  87285b34884572647811a353c7ac498a   29.99
# 1  b0830fb4747a6c6d20dea0b8c802d7ef  595fac2a385ac33a80bd5114aec74eb8  118.70
# 2  41ce2a54c0b03bf3443c3d931a367089  aa4383b373c6aca5d8797843e5594415  159.90
# 3  f88197465ea7920adcdbec7375364d82  d0b61bfb1de832b15ba9d266ca96e5b0   45.00
# 4  8ab97904e6daea8866dbdbc4fb7aad2c  65266b2da20d04dbe00c5c2d3bb7859e   19.90
#
#    freight_value product_name  product_name_length  \
# 0           8.72   housewares                 40.0
# 1          22.76    perfumery                 29.0
# 2          19.22         auto                 46.0
# 3          27.20     pet_shop                 59.0
# 4           8.72   stationery                 38.0
#
#    product_description_length  product_photos_qty            customer_city  \
# 0                       268.0                 4.0                sao paulo
# 1                       178.0                 1.0                barreiras
# 2                       232.0                 1.0               vianopolis
# 3                       468.0                 3.0  sao goncalo do amarante
# 4                       316.0                 4.0              santo andre
#
#   estimated_delivery_date actual_delivery_date  review_score  is_delayed
# 0              2017-10-18  2017-10-10 21:25:13             4       False
# 1              2018-08-13  2018-08-07 15:27:45             4       False
# 2              2018-09-04  2018-08-17 18:06:29             5       False
# 3              2017-12-15  2017-12-02 00:28:42             5       False
# 4              2018-02-26  2018-02-16 18:17:02             5       False

# %%
encoder = LabelEncoder()
df['encoded_is_delayed'] = encoder.fit_transform(df['is_delayed'])

# %%
df['encoded_is_delayed'].value_counts()
# Out:
# encoded_is_delayed
# 0    102331
# 1      8419
# Name: count, dtype: int64

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >
